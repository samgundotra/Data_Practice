# %%
from bs4 import BeautifulSoup as bs
import numpy as np
import pandas as pd
import requests

# %%
#SWEET HOME ALABAMA
url = 'https://www.ukulele-tabs.com/uke-songs/lynyrd-skynyrd/sweet-home-alabama-uke-tab-9520.html'
r = requests.get(url)
html = r.content

a = bs(html, 'lxml')
a = a.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

a_data = []
for c in a:
    print(c.text)
    a_data.append(c.text)
# Out:
# D
# C
# G
# D
# C
# G
# D
# C
# G
# D
# C
# G
# A
# D
# C
# G
# D
# C
# G
# D
# C
# G
# D
# C
# G

# %%
#HOTLINE BLING
url = 'https://www.ukulele-tabs.com/uke-songs/drake/hotline-bling-uke-tab-44808.html'
r = requests.get(url)
html = r.content

b = bs(html, 'lxml')
b = b.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

b_data = []
for c in b:
    print(c.text)
    b_data.append(c.text)
# Out:
# Bb
# Gm
# Bb
# Gm
# Bb
# Gm
# Bb
# Gm
# Bb
# Gm
# Bb
# C
# Bb
# Gm
# Bb
# D
# Bb
# Gm
# Bb
# Gm
# Bb
# Gm
# Bb
# Gm
# Bb
# Gm
# Bb
# C
# Bb
# Gm
# Bb
# D
# Bb
# Gm
# Bb
# Gm
# Bb
# Gm
# Bb
# Gm
# Bb
# Gm
# C
# C
# C
# Bb
# Gm
# Gm
# C
# C
# C
# Bb
# Gm
# Bb
# Gm
# Bb
# Gm
# Bb
# Gm
# Bb
# Gm

# %%
#DESPACITO
url = 'https://www.ukulele-tabs.com/uke-songs/luis-fonsi/despacito-uke-tab-50770.html'
r = requests.get(url)
html = r.content

d = bs(html, 'lxml')
d = d.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

d_data = []
for c in d:
    print(c.text)
    d_data.append(c.text)
# Out:
# Bm
# G
# D
# A
# Bm
# G
# D
# A
# Bm
# G
# D
# A
# Bm
# G
# D
# A
# Bm
# G
# D
# A
# Bm
# G
# D
# A
# Bm
# G
# D
# A
# Bm
# G
# D
# G
# D
# A
# A
# D
# D
# G
# G
# D
# A
# D
# Bm
# G
# G
# D
# A
# A
# Bm
# Bm
# G
# G
# D
# A
# Bm
# G
# D
# A
# Bm
# G
# D
# A
# Bm
# G
# D
# A
# Bm
# G
# D
# A
# Bm
# G
# D
# D
# A
# Bm
# G
# D
# A
# Bm
# G
# D
# A
# Bm
# G
# D
# G
# D
# A
# A
# Bm

# %%
#KNOW WHAT I WANT
url = 'https://www.ukulele-tabs.com/uke-songs/kali-uchis/know-what-i-want-uke-tab-49562.html'
r = requests.get(url)
html = r.content

e = bs(html, 'lxml')
e = e.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

e_data = []
for c in e:
    print(c.text)
    e_data.append(c.text)
# Out:
# F#
# F#
# C#
# B
# F#
# C#
# F#
# C#
# F#
# F#
# B
# C#
# B
# B
# F#
# C#
# B
# F#
# C#

# %%
#SEE YOU AGAIN
url = 'https://www.ukulele-tabs.com/uke-songs/tyler-the-creator/see-you-again-uke-tab-55788.html'
r = requests.get(url)
html = r.content

f = bs(html, 'lxml')
f = f.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

f_data = []
for c in f:
    print(c.text)
    f_data.append(c.text)
# Out:
# Fmaj7
# Dm
# Gm7
# Gdim
# Fmaj7
# Dm
# Gm7
# Gdim
# Fmaj7
# Dm
# Gm7
# Gdim
# Fmaj7
# Dm
# Gm7
# Gdim
# Fmaj7
# Dm
# Gm7
# Gdim
# Fmaj7
# Dm
# Gm7
# Gdim
# Fmaj7
# Em7
# B
# Gm7
# Fmaj7
# Em7
# B
# Gm7
# Fmaj7
# Dm
# Gm7
# Gdim
# Fmaj7
# Dm
# Gm7
# G7
# Fmaj7
# Dm
# Gm7
# Gdim
# Fmaj7
# Dm
# Gm7
# Gdim

# %%
#STAY
url = 'https://www.ukulele-tabs.com/uke-songs/post-malone/stay-uke-tab-58715.html'
r = requests.get(url)
html = r.content

g = bs(html, 'lxml')
g = g.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

g_data = []
for c in g:
    print(c.text)
    g_data.append(c.text)
# Out:
# F
# C
# Am
# C
# Am
# G
# E
# F
# C
# Am
# Gm
# A#
# F
# C
# Am
# D
# F
# F
# C
# F
# C
# C
# C
# Am
# D
# F
# Fm
# F
# F
# C
# Am
# Gm
# F
# C

# %%
#SAVED
url = 'https://www.ukulele-tabs.com/uke-songs/khalid/saved-uke-tab-54214.html'
r = requests.get(url)
html = r.content

h = bs(html, 'lxml')
h = h.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

h_data = []
for c in h:
    print(c.text)
    h_data.append(c.text)
# Out:
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm
# F
# Am
# G
# Dm

# %%
#HOMECOMING
url = 'https://www.ukulele-tabs.com/uke-songs/kanye-west/homecoming-uke-tab-4256.html'
r = requests.get(url)
html = r.content

i = bs(html, 'lxml')
i = i.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

i_data = []
for c in i:
    print(c.text)
    i_data.append(c.text)
# Out:
# Fm
# Eb
# Fm
# Eb
# Fm
# Ab
# Bbm7
# C#M7
# Cm
# Fm
# Cm
# Fm
# A
# Fm
# Eb

# %%
#SELF CONTROL
url = 'https://www.ukulele-tabs.com/uke-songs/frank-ocean/self-control-uke-tab-53572.html'
r = requests.get(url)
html = r.content

j = bs(html, 'lxml')
j = j.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

j_data = []
for c in j:
    print(c.text)
    j_data.append(c.text)
# Out:
# Gmaj7
# Em7
# Am7
# D7
# Gmaj7
# Em7
# Am7
# D7
# Gmaj7
# Em7
# Am7
# D7
# Gmaj7
# Em7
# Am7
# D7
# Gmaj7
# Em7

# %%
#LOVING IS EASY
url = 'https://www.ukulele-tabs.com/uke-songs/rex-orange-county/loving-is-e-asy-uke-tab-56547.html'
r = requests.get(url)
html = r.content

k = bs(html, 'lxml')
k = k.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

k_data = []
for c in k:
    print(c.text)
    k_data.append(c.text)
# Out:
# C
# Dm
# Em
# Dm
# C
# Dm
# Em
# C
# G
# C
# Dm
# Em
# G
# F
# F
# Em
# F
# Em
# F
# D#
# D#
# Dm
# G
# C
# Dm
# Em
# C
# Dm
# Em
# G
# C
# Dm
# Em
# G
# C
# G
# C
# Dm
# Em
# G
# F
# Em
# F
# Em
# F
# Em
# D#
# Dm
# G
# C
# Dm
# Em
# C
# Dm
# Em
# G
# C
# Dm
# Em
# G
# C
# G
# C
# Dm
# Em
# G

# %%
#FEELS
url = 'https://www.ukulele-tabs.com/uke-songs/calvin-harris/feels-uke-tab-55060.html'
r = requests.get(url)
html = r.content

l = bs(html, 'lxml')
l = l.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

l_data = []
for c in l:
    print(c.text)
    l_data.append(c.text)
# Out:
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# A
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# A
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# B
# C
# D
# Em
# Em
# A
# B
# C
# D
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B
# Em
# A
# F#m
# B

# %%
#CHASING PAVEMENTS
url = 'https://www.ukulele-tabs.com/uke-songs/adele/chasing-pavements-uke-tab-16053.html'
r = requests.get(url)
html = r.content

m = bs(html, 'lxml')
m = m.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

m_data = []
for c in m:
    print(c.text)
    m_data.append(c.text)
# Out:
# Cm
# Gm
# G#
# Gm
# G#
# A#
# D#
# Cm
# Gm
# D#
# Gm
# Cm
# Gm
# G#
# A#
# G#
# D#
# Fm
# C#
# A#m
# A#m
# C#
# D#
# G#
# D#
# Fm
# C#
# A#m
# D#
# G#
# D#
# Fm
# C#
# A#m
# C#
# A#m
# D#
# G#
# Cm
# Gm
# Cm
# Gm
# G#
# A#
# G#
# D#
# Fm
# C#
# A#m
# A#m
# C#
# D#
# G#
# D#
# Fm
# C#
# A#m
# D#
# G#
# D#
# Fm
# C#
# A#m
# C#
# A#m
# D#
# G#

# %%
#MAKE U FEEL MY LOVE
url = 'https://www.ukulele-tabs.com/uke-songs/adele/make-you-feel-my-love-uke-tab-21668.html'
r = requests.get(url)
html = r.content

n = bs(html, 'lxml')
n = n.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

n_data = []
for c in n:
    print(c.text)
    n_data.append(c.text)
# Out:
# G
# D
# F
# C
# Cm
# G
# A7
# D7
# G
# G
# D
# F
# C
# Cm
# G
# A7
# D7
# G
# C
# G
# B7
# C
# G
# C
# G
# A7
# D7
# G
# D
# F
# C
# Cm
# G
# A7
# D7
# G
# G
# D
# F
# C
# Cm
# G
# A7
# D7
# G
# C
# G
# B7
# C
# G
# C
# G
# A7
# D7
# C/D
# G
# D
# F
# C
# Cm
# G
# A7
# D7
# G
# Cm
# G
# A7
# D7
# G

# %%
#PUT YOUR RECORDS ON
url = 'https://www.ukulele-tabs.com/uke-songs/corinne-bailey-rae/put-your-records-on-uke-tab-7916.html'
r = requests.get(url)
html = r.content

o = bs(html, 'lxml')
o = o.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

o_data = []
for c in o:
    print(c.text)
    o_data.append(c.text)
# Out:
# E9
# A
# Fm7
# A
# F#
# E6
# E9
# A
# E
# A
# A
# F#m7
# F#m7
# E6
# E9
# A
# F#m7
# C#7
# F#m7
# B7
# Dmaj7
# Dm7
# Dm7
# Dmaj7
# Dm7
# A
# F#m7
# C#7
# F#m7
# B7
# Dmaj7
# Dm7
# Dm7
# Bm7
# F#m7
# Bm7
# Dmaj7
# Bm7
# Bm7
# Bm7

# %%
#MISERY
url = 'https://www.ukulele-tabs.com/uke-songs/maroon-5/misery-uke-tab-20242.html'
r = requests.get(url)
html = r.content

p = bs(html, 'lxml')
p = p.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

p_data = []
for c in p:
    print(c.text)
    p_data.append(c.text)
# Out:
# B
# Em
# C
# B
# Em
# C
# B
# Em
# C
# B
# Em
# C
# B
# Em
# Am
# D
# G
# Em
# Am
# D
# G
# Em
# Am
# D
# G
# Em
# Am
# D
# G
# Em
# Am
# D
# G
# Em
# Am
# D
# G
# C
# B
# Em
# G
# C
# B
# G
# B
# Em
# Am
# D
# G
# Em
# Am
# D
# G
# Em
# Am
# D
# G
# Em
# Am
# D
# G

# %%
#SUNDAY MORNING
url = 'https://www.ukulele-tabs.com/uke-songs/maroon-5/sunday-morning-uke-tab-18485.html'
r = requests.get(url)
html = r.content

q = bs(html, 'lxml')
q = q.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

q_data = []
for c in q:
    print(c.text)
    q_data.append(c.text)
# Out:
# Dm
# G7
# C
# C
# Dm
# G7
# C
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# C
# Dm
# G7
# C
# C
# Dm
# G7
# C
# C
# Dm
# G7
# C
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# Dm
# G7
# C
# C
# Dm
# G7
# C
# C
# Dm
# G7
# C
# C
# Dm
# G7
# C
# C
# Dm
# G7
# C
# C

# %%
#BEST OF MY LOVE
url = 'https://www.ukulele-tabs.com/uke-songs/the-eagles/best-of-my-love-uke-tab-1081.html'
r = requests.get(url)
html = r.content

s = bs(html, 'lxml')
s = s.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

s_data = []
for c in s:
    print(c.text)
    s_data.append(c.text)
# Out:
# C
# C
# Dm
# Dm
# C
# C
# Dm
# Dm
# C
# C
# Dm
# Dm
# Em
# Dm
# Em
# F/G
# C
# Dm
# C
# G7
# C
# C
# Dm
# Dm
# C
# C
# Dm
# Dm
# Em
# Dm
# Em
# F/G
# C
# Dm
# C
# G7
# C
# C
# Dm
# Dm
# C
# C
# Dm
# Dm
# Fm7
# Fm7
# C
# C
# Fm7
# Fm7
# Dm
# G7
# C
# C
# Dm
# Dm
# C
# C
# Dm
# Dm
# Em
# Dm
# Em
# Dm
# G7
# C
# Dm
# C
# G
# C
# C
# Dm
# Dm
# C
# C
# Dm
# Dm

# %%
#HOTEL CALIFORNIA
url = 'https://www.ukulele-tabs.com/uke-songs/the-eagles/hotel-california-uke-tab-4299.html'
r = requests.get(url)
html = r.content

t = bs(html, 'lxml')
t = t.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

t_data = []
for c in t:
    print(c.text)
    t_data.append(c.text)
# Out:
# Am
# E7
# G
# D
# F
# C
# Dm
# E
# Am
# E7
# G
# D
# F
# C
# Dm
# E
# Am
# E7
# G
# D
# F
# C
# Dm
# E
# F
# C
# E7
# Am
# F
# C
# Dm
# E
# Am
# E7
# G
# D
# F
# C
# Dm
# E
# Am
# E7
# G
# D
# F
# C
# Dm
# E
# F
# C
# E7
# Am
# F
# C
# Dm
# E
# Am
# E7
# G
# D
# F
# C
# Dm
# E
# Am
# E7
# G
# D
# F
# C
# Dm
# E
# F
# C
# E7
# Am
# F
# C
# Dm
# E

# %%
#MIRRORS
url = 'https://www.ukulele-tabs.com/uke-songs/justin-timberlake/mirrors-uke-tab-47440.html'
r = requests.get(url)
html = r.content

u = bs(html, 'lxml')
u = u.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

u_data = []
for c in u:
    print(c.text)
    u_data.append(c.text)
# Out:
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# D
# A
# G
# D
# A
# G
# D
# A
# Em
# Bm
# D
# A
# G
# D
# A
# G
# D
# A
# G
# D
# A
# Em
# Bm
# D
# A
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# D
# A
# G
# D
# A
# G
# D
# A
# Em
# Bm
# D
# A
# G
# D
# A
# G
# D
# A
# G
# D
# A
# Em
# Bm
# D
# A
# G
# Em
# Bm
# Em
# Bm
# A
# Em
# Bm
# G
# A
# G
# D
# A
# G
# D
# A
# G
# D
# A
# Em
# Bm
# D
# A
# G
# D
# A
# G
# D
# A
# G
# D
# A
# Em
# Bm
# D
# A
# G
# D
# A
# G
# D
# A
# G
# Bm
# A
# G
# D
# A
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G
# Bm
# A
# Em
# G

# %%
#LOVE ON TOP
url = 'https://www.ukulele-tabs.com/uke-songs/beyonce-knowles/love-on-top-uke-tab-23577.html'
r = requests.get(url)
html = r.content

v = bs(html, 'lxml')
v = v.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

v_data = []
for c in v:
    print(c.text)
    v_data.append(c.text)
# Out:
# E
# B
# Abm
# F#
# E
# B
# Abm
# F#
# Abm
# B
# F#
# Gbaug
# Abm
# B
# F#
# Gbaug
# E
# B
# Abm
# F#
# E
# B
# Abm
# F#
# E
# B
# Abm
# F#
# E
# B
# Abm
# F#

# %%
#THATS WHAT I LIKE
url = 'https://www.ukulele-tabs.com/uke-songs/bruno-mars/thats-what-i-like-uke-tab-51534.html'
r = requests.get(url)
html = r.content

w = bs(html, 'lxml')
w = w.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

w_data = []
for c in w:
    print(c.text)
    w_data.append(c.text)
# Out:
# Dm
# Dm
# Dm
# F
# F
# F
# Em7
# Em7
# Em7
# A
# A
# A7
# Dm
# Dm
# Dm
# F
# F
# Em7
# Em7
# Em7
# A
# A
# A7
# Dm
# Em7
# F
# Dm
# Em7
# Am
# G
# Em7
# Dm
# Dm
# F
# F
# Em7
# Em7
# A
# A
# Dm
# Dm
# F
# F
# Em7
# Em7
# Am
# G
# F
# Em7
# Dm
# Dm
# Dm
# F
# F
# Em7
# Em7
# A
# A
# Am
# Dm
# Dm
# Dm
# F
# F
# Em7
# Em7
# Em7
# A
# A
# A7
# Dm
# Em7
# F
# Dm
# Em7
# Am
# G
# Em7
# Dm
# Dm
# F
# F
# Em7
# Em7
# A
# A
# Dm
# Dm
# F
# F
# Em7
# Em7
# Am
# G
# F
# Em7
# F
# Em7
# A
# A
# F
# Dm
# Em7
# C
# F
# E7
# E
# F
# G
# Am7
# Am
# Dm
# Dm
# Em7
# Am
# G
# Em7
# Dm
# Dm
# F
# F
# Em7
# Em7
# A
# A
# Dm
# Dm
# F
# F
# Em7
# Em7
# Am
# G
# F
# Em7
# Am

# %%
#OUR SONG
url = 'https://www.ukulele-tabs.com/uke-songs/taylor-swift/our-song-uke-tab-7478.html'
r = requests.get(url)
html = r.content

x = bs(html, 'lxml')
x = x.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

x_data = []
for c in x:
    print(c.text)
    x_data.append(c.text)
# Out:
# D
# Em7
# G
# A
# D
# Em
# G
# A
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# Em
# A
# Em7
# D
# G
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# Em7
# A
# Em7
# D
# G
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# Em7
# G
# D
# A
# Em7
# G
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# Em7
# A
# Em7
# D
# G
# D
# Em7
# G
# A
# D
# Em7
# G
# A
# D
# Em7
# A
# D
# Em7
# G
# A
# D
# Em7
# G

# %%
#CAN'T HELP FALLING IN LOVE
url = 'https://www.ukulele-tabs.com/uke-songs/elvis-presley/cant-help-falling-in-love-uke-tab-51645.html'
r = requests.get(url)
html = r.content

y = bs(html, 'lxml')
y = y.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

y_data = []
for c in y:
    print(c.text)
    y_data.append(c.text)
# Out:
# F
# G
# Am
# F
# C
# G7
# C
# G7
# C
# Em
# Am
# F
# C
# G
# F
# G
# Am
# F
# C
# G7
# C
# C
# Em
# Am
# F
# C
# G
# F
# G
# Am
# F
# C
# G7
# C
# Em
# B7
# Em
# B7
# Em
# B7
# Em
# A7
# Dm
# G7
# C
# Em
# Am
# F
# C
# G
# F
# G
# Am
# F
# C
# G7
# C
# Em
# B7
# Em
# B7
# Em
# B7
# Em
# A7
# Dm
# G7
# C
# Em
# Am
# F
# C
# G
# F
# G
# Am
# F
# C
# G7
# C
# F
# G
# Am
# F
# C
# G7
# C

# %%
#STRANGERS IN THE NIGHT
url = 'https://www.ukulele-tabs.com/uke-songs/frank-sinatra/strangers-in-the-night-uke-tab-33279.html'
r = requests.get(url)
html = r.content

z = bs(html, 'lxml')
z = z.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

z_data = []
for c in z:
    print(c.text)
    z_data.append(c.text)
# Out:
# F
# Fmaj7
# C
# F
# Fmaj7
# F
# Fmaj7
# Gm
# Gm
# Gm7
# Gm
# Gm7
# Gm
# C
# F
# Am
# D7
# Am
# D7
# Am
# D7
# Am
# D7
# Gm
# Gm7
# Gm
# F
# Gm
# C
# A
# F
# Fmaj7
# F
# C7
# F
# Am
# D7
# Am
# D7
# Am
# D7
# Am
# D7
# Gm
# Gm7
# Gm
# F
# Gm
# C
# A
# G
# Gmaj7
# G6
# D
# G

# %%
#THE WAY YOU LOOK TONIGHT
url = 'https://www.ukulele-tabs.com/uke-songs/frank-sinatra/the-way-you-look-tonight-uke-tab-35941.html'
r = requests.get(url)
html = r.content

ab = bs(html, 'lxml')
ab = ab.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

ab_data = []
for c in ab:
    print(c.text)
    ab_data.append(c.text)
# Out:
# Gmaj7
# Em7
# Amaj7
# D7
# Gmaj7
# Em7
# Amaj7
# D7
# Bm7
# E7
# Amaj7
# D7
# Gmaj7
# Em7
# Amaj7
# D7
# Gmaj7
# Em7
# Amaj7
# D7
# Gmaj7
# Em7
# Amaj7
# D7
# Gmaj7
# Em7
# Amaj7
# D7
# Bm7
# E7
# Amaj7
# D7
# Gmaj7
# Em7
# Amaj7
# D7
# Gmaj7
# Em7
# Amaj7
# D7
# A#maj7
# Bdim7
# Cm7
# F7
# Dmaj7
# Bdim
# Cm7
# F7
# Dmaj7
# G7sus4
# Cm7
# F7
# A#maj7
# Bdim7
# Amaj7
# D7
# Gmaj7
# Em7
# Amaj7
# D7
# Bm7
# E7
# Amaj7
# D7
# Gmaj7
# Em7
# Amaj7
# D7
# Gmaj7
# Em7
# Amaj7
# D7
# Gmaj7

# %%
#IM YOURS
url = 'https://www.ukulele-tabs.com/uke-songs/jason-mraz/im-yours-uke-tab-12044.html'
r = requests.get(url)
html = r.content

ac = bs(html, 'lxml')
ac = ac.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

ac_data = []
for c in ac:
    print(c.text)
    ac_data.append(c.text)
# Out:
# B
# F#
# G#m
# E
# B
# F#
# G#m
# E
# B
# F#
# G#m
# E
# B
# F#
# G#m
# E
# B
# F#
# G#m
# E
# Em
# B
# F#
# G#m
# E
# B
# F#
# G#m
# E
# B
# F#
# G#m
# E
# B
# F#
# G#m
# E
# B
# F#
# G#m
# E
# B
# F#
# G#m
# E
# B
# F#
# G#m
# E
# B
# F#
# G#m
# E

# %%
#MEET ME HALFWAY
url = 'https://www.ukulele-tabs.com/uke-songs/black-eyed-peas/meet-me-halfway-uke-tab-13386.html'
r = requests.get(url)
html = r.content

ad = bs(html, 'lxml')
ad = ad.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

ad_data = []
for c in ad:
    print(c.text)
    ad_data.append(c.text)
# Out:
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# Am
# G
# Em
# F
# G
# Em
# F
# G
# Em
# F
# G
# Em
# F
# G
# Em
# F
# Dm
# Em
# Am
# G
# Dm
# Em
# F
# G
# Am
# G/B
# Em
# F

# %%
#BILLIE JEAN
url = 'https://www.ukulele-tabs.com/uke-songs/michael-jackson/billie-jean-uke-tab-33044.html'
r = requests.get(url)
html = r.content

ae = bs(html, 'lxml')
ae = ae.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

ae_data = []
for c in ae:
    print(c.text)
    ae_data.append(c.text)
# Out:
# Em
# Em
# Am
# Em
# Am
# Em
# Am
# Em
# C
# Em
# C
# Em
# C
# Em
# C
# B7
# Em
# Am
# Em
# G
# Em
# Am
# Em
# Am
# Bm
# G
# Bm7
# Em
# Am
# G
# Bm7
# Em
# Em
# Am
# Em
# Am
# Em
# Em
# Am
# Em
# C
# Em
# C
# Em
# C
# Em
# C
# B7
# Em
# Am
# Em
# G
# Em
# Am
# Em
# Am
# Bm
# G
# Bm7
# Em
# Am
# G
# Bm7
# Em
# Am
# Em

# %%
#THRILLER
url = 'https://www.ukulele-tabs.com/uke-songs/michael-jackson/thriller-uke-tab-15616.html'
r = requests.get(url)
html = r.content

af = bs(html, 'lxml')
af = af.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

af_data = []
for c in af:
    print(c.text)
    af_data.append(c.text)
# Out:
# Am
# C
# D
# Am7
# D7
# Am7
# D7
# Am7
# D7
# Am7
# D7
# Am7
# Fmaj7
# Em
# Am
# C
# D
# Am7
# D7
# Dm7
# Am
# C
# D
# Am7
# D7
# F7
# D7
# F/G
# Am7
# D7
# Am7
# D7
# Am7
# D7
# Am7
# D7
# Am7
# Fmaj7
# Em
# Am
# C
# D
# Am7
# D7
# Dm7
# Am
# C
# D
# Am7
# D7
# F7
# D7
# F/G
# Am7
# D7
# Fmaj9
# G
# Am7
# C/G
# Em
# Fmaj7
# E7sus4
# E7
# D7
# Am7
# D7
# Am7
# D7
# Am7
# D7
# Am7
# Fmaj7
# Em
# Am
# C
# D
# Am7
# D7
# Dm7
# Am
# C
# D
# Am7
# D7
# F7
# D7
# F/G
# Am7
# C

# %%
#EVERYBODY WANTS TO RULE THE WORLD
url = 'https://www.ukulele-tabs.com/uke-songs/tears-for-fears/everybody-wants-to-rule-the-world-uke-tab-52371.html'
r = requests.get(url)
html = r.content

ah = bs(html, 'lxml')
ah = ah.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

ah_data = []
for c in ah:
    print(c.text)
    ah_data.append(c.text)
# Out:
# Dmaj7
# G6
# Dmaj7
# G6
# Dmaj7
# G6
# G6
# Em
# F#m
# G
# F#m
# Em
# F#m
# G
# A
# Dmaj7
# G6
# Dmaj7
# G6
# Dmaj7
# G6
# Dmaj7
# G6
# Dmaj7
# G6
# Dmaj7
# G6
# G6
# Em
# F#m
# G
# F#m
# Em
# F#m
# G
# A
# G
# D
# D
# A
# A
# G
# D
# D
# A
# A
# G
# G
# D
# D
# A
# A
# Em
# F#m
# G
# F#m
# Em
# F#m
# G
# A
# G
# D
# A
# G
# D
# A
# Em
# F#m
# G
# F#m
# Em
# F#m
# G
# A
# Dmaj7
# G6
# Dmaj7
# G6
# Dmaj7
# G6
# Dmaj7
# G6
# Dmaj7
# G6

# %% [markdown]
# # 30

# %%
#EYE OF THE TIGER
url = 'https://www.ukulele-tabs.com/uke-songs/survivor/eye-of-the-tiger-uke-tab-22851.html'
r = requests.get(url)
html = r.content

ai = bs(html, 'lxml')
ai = ai.find_all("a", {"class","ut_crd_tooltip ukechord_tooltip chord"})

ai_data = []
for c in ai:
    print(c.text)
    ai_data.append(c.text)
# Out:
# Am
# F
# G
# Am
# Am
# F
# G
# Am
# Am
# F
# G
# Am
# Am
# F
# G
# Am
# F
# C
# G
# F
# G
# F
# C
# G
# F
# G
# Am
# Am
# F
# G
# Am
# Am
# F
# G
# Am
# F
# C
# G
# F
# G
# F
# C
# G
# F
# G
# Am
# Am
# F
# G
# Am
# Am
# F
# G
# Am
# F
# C
# G
# F
# G
# F
# C
# G
# F
# G
# Am
